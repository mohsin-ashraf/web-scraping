# %%
#This time using mechanize instead of using urllib
import mechanize
#This time using lxml instead of using bs4 BeautifulSoup
import lxml.html
#time library is used to sleep between the requests that are made getting iteratively data from website
import time

# %%
browser = mechanize.Browser()
browser.set_handle_robots(False)
browser.addheaders = [("user-agent","Chrome")]

# %%
url_to_apple_stock_value = "https://www.bloomberg.com/quote/AAPL:US"

# %%
apple_html = browser.open(url_to_apple_stock_value)

# %%
apple_html.code
# Out:
# 200

# %%
apple_html = apple_html.read()

# %%
apple_html
# Out:
# '\n<!DOCTYPE html>\n<html>\n    <head>\n        \n            <title>AAPL:NASDAQ GS Stock Quote - Apple Inc - Bloomberg Markets</title>\n            <meta name="title" content="AAPL:NASDAQ GS Stock Quote - Apple Inc">\n        \n        \n            <meta name="description" content="Stock analysis for Apple Inc (AAPL:NASDAQ GS) including stock price, stock chart, company news, key statistics, fundamentals and company profile.">\n            <meta name="keywords" content="Apple Inc, Apple Inc stock, Apple Inc stock price, Apple Inc stock charts, AAPL price quote, AAPL quote, Apple Inc news, AAPL, AAPL stock, AAPL stock price, AAPL stock charts, stock, stock price, stock charts">\n            <link rel="shortcut icon" type="image/png" href="/images/favicon-markets.png"/>\n            <meta property="og:site_name" content="Bloomberg.com">\n            <meta property="og:title" content="AAPL:NASDAQ GS Stock Quote - Apple Inc">\n            <meta property="og:description" content="Stock analysis for Apple Inc (AAPL:NASDAQ GS) including stock price, stock chart, company news, key statistics, fundamentals and company profile.">\n            <meta property="og:image" content="/images/markets-logo.png">\n            <meta property="og:type" content="company">\n            <meta property="og:url" content="https://www.bloomberg.com/quote/AAPL:US">\n            <meta name="twitter:card" content="summary">\n            <meta name="twitter:description" content="Stock analysis for Apple Inc (AAPL:NASDAQ GS) including stock price, stock chart, company news, key statistics, fundamentals and company profile.">\n            <meta name="twitter:site" content="@markets">\n            <meta name="twitter:title" content="AAPL:NASDAQ GS Stock Quote - Apple Inc">\n            <meta name="twitter:url" content="https://www.bloomberg.com/quote/AAPL:US">\n            <link rel="canonical" href="https://www.bloomberg.com/quote/AAPL:US">\n        \n        <link type="text/css" rel="stylesheet" href="https://assets.bwbx.io/s3/bbgmkts/assets/normalize-bb22b1681acf23ebc5cab8fadea393a7.css" />\n        <link type="text/css" rel="stylesheet" href="https://assets.bwbx.io/s3/bbgmkts/assets/quote-51b1e3020819016151c577c94b9935f4.css" />\n        <link type="text/css" rel="stylesheet" href="https://assets.bwbx.io/font-service/css/AvenirNext-Demi%2CBloomberg%2CBWHaasText-55Roman%2CBWHaasText-65Medium%2CBWHaasText-75Bold%2CBW%20Haas%20Text%20Mono%20A-55%20Roman%2CBloomberg%20Logotypes-Medium%2CTiemposHeadlineWeb-Bold%2CBWHaasHead-95Black/font-face.css" />\n        <link rel="stylesheet" type="text/css" href="https://www.bbthat.com/assets/v2.0.2/that.css"/>\n        <link rel="stylesheet" type="text/css" href="https://assets.bwbx.io/font-service/css/Bloomberg%20Logotypes-Medium,BWHaasGrotesk-75Bold-Web,BWHaasGrotesk-95Black-Web,BWHaasGrotesk-55Roman-Web/font-face.css"/><link rel="stylesheet" type="text/css" href="https://assets.bwbx.io/s3/navi/css/components/bar/bar-fa18e40403.css"/><link rel="stylesheet" type="text/css" href="https://assets.bwbx.io/s3/navi/vendor/css/reg-ui-client-162e0da6e2.css"/>\n        <link rel="stylesheet" type="text/css" href="https://assets.bwbx.io/font-service/css/Bloomberg/font-face.css"/><link rel="stylesheet" type="text/css" href="https://nav.bloomberg.com/public/stylesheets/bb-global-footer-af4496cb6b.css"/>\n        <script type="text/javascript" src="https://assets.bwbx.io/s3/bbgmkts/assets/geoip-3050fd9514383dacc790.js"></script>\n        <script type="text/javascript" src="https://assets.bwbx.io/s3/bbgmkts/assets/personalization-df24bcb3b4af620bca70.js"></script>\n        <script type="text/javascript">\n            window._taboola = window._taboola || [];\n            _taboola.push({category:\'auto\'});\n            !function (e, f, u, i) {\n            if (!document.getElementById(i)){\n            e.async = 1;\n            e.src = u;\n            e.id = i;\n            f.parentNode.insertBefore(e, f);\n        }\n        }(\n    ...

# %%
tree = lxml.html.fromstring(apple_html)

# %%
price = tree.xpath('//span[@class="priceText__1853e8a5"]')

# %%
price = price[0]
price.text_content()
# Out:
# '186.19'

# %%
stock_price = float(price.text_content())
stock_price
# Out:
# 186.19

# %% [markdown]
# # Getting stock information iteratively

# %%
for i in range(10):#You can put whatever number you want here...
    apple_html = browser.open(url_to_apple_stock_value).read()
    tree = lxml.html.fromstring(apple_html)
    price = tree.xpath('//span[@class="priceText__1853e8a5"]')
    price = price[0]
    print price.text_content()
    time.sleep(2)
# Out:
# 186.19
# 186.19
# 186.19
# 186.19
# 186.19
# 186.19
# 186.19
# 186.19
# 186.19
# 186.19

# %% [markdown]
# ### Requesting too many times to the same website in a very short time can block your ip address.
# <img src = 'imgs/mimitw.jpg'>
